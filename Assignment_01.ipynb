# %% [markdown]
# <a href="https://colab.research.google.com/github/thcen-dev/ai-health-data-project/blob/main/Assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is Assignment One of my IT 287 Independent Study Course

# %%
import pandas as pd

# Replace 'your_file_path.csv' with the actual path to your CSV file
df = pd.read_csv('/content/synthetic_dmerc_base (1).csv')

# This shows the dimensions of the data frame
df.shape
# Out:
# (839, 52)

# %%
df.dtypes
# Out:
# DSYSRTKY                   int64
# CLAIMNO                    int64
# THRU_DT                    int64
# RIC_CD                    object
# CLM_TYPE                   int64
# DISP_CD                    int64
# CARR_NUM                   int64
# PMTDNLCD                  object
# PMT_AMT                    int64
# PRPAYAMT                 float64
# ASGMNTCD                  object
# PROV_PMT                   int64
# BENE_PMT                   int64
# SBMTCHRG                 float64
# ALOWCHRG                   int64
# DEDAPPLY                 float64
# HCPCS_YR                   int64
# PRNCPAL_DGNS_CD           object
# PRNCPAL_DGNS_VRSN_CD       int64
# RFR_UPIN                 float64
# RFR_NPI                    int64
# DOB_DT                     int64
# RACE_CD                    int64
# CNTY_CD                    int64
# STATE_CD                   int64
# CWF_BENE_MDCR_STUS_CD      int64
# CLM_BENE_PD_AMT            int64
# ACO_ID_NUM               float64
# ...
